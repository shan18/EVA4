# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from torchsummary import summary

from cuda import initialize_cuda
from result import class_level_accuracy, plot_metric, save_and_show_result
from train import train
from evaluate import val
from model.resnet import ResNet18
from model.utils.loss import cross_entropy_loss
from model.utils.optimizers import sgd_optimizer
from data.dataset import CIFAR10

# %% [markdown]
# # Configuration
#
# Set various parameters and hyperparameters

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Augmentation
    # ============
    horizontal_flip = 0.2
    vertical_flip = 0.1
    rotation = 10
    random_erasing = 0.3

    # Training
    # ========
    random_seed = 1
    epochs = 50
    learning_rate = 0.01
    momentum = 0.9

    # Evaluation
    # ==========
    sample_count = 25

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the CIFAR-10 class to download dataset and create data loader

# %%
dataset = CIFAR10(
    train_batch_size=Args.train_batch_size,
    val_batch_size=Args.val_batch_size,
    cuda=cuda,
    num_workers=Args.num_workers,
    horizontal_flip=Args.horizontal_flip,
    vertical_flip=Args.vertical_flip,
    rotation=Args.rotation,
    random_erasing=Args.random_erasing
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/data/cifar10/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /content/data/cifar10/cifar-10-python.tar.gz to /content/data/cifar10
# Files already downloaded and verified

# %% [markdown]
# ## Data Visualization
# Let's see how our data looks like. This information will help us decide the transformations that can be used on the dataset.

# %%
# Fetch data
classes = dataset.classes()
sample_data, sample_targets = dataset.data()

# Set number of images to display
num_images = 4

# Display images with labels
fig, axs = plt.subplots(1, 4, figsize=(8, 8))
fig.tight_layout()

for i in range(num_images):
    axs[i].axis('off')
    axs[i].set_title(f'Label: {classes[sample_targets[i]]}')
    axs[i].imshow(sample_data[i])

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18().to(device)  # Create model
summary(model, dataset.image_size())  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Model Training and Validation

# %%
losses = []
accuracies = []
correct_samples = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd_optimizer(model, Args.learning_rate, Args.momentum)  # Create optimizer
last_epoch = False

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    if epoch == Args.epochs:
        last_epoch = True
    train(model, train_loader, device, optimizer, criterion)
    val(
        model, val_loader, device, criterion, losses, accuracies,
        correct_samples, incorrect_samples, Args.sample_count, last_epoch=last_epoch
    )
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=1.14 Batch_ID=781 Accuracy=45.99: 100%|██████████| 782/782 [00:58<00:00, 13.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0180, Accuracy: 5817/10000 (58.17%)
#
# Epoch 2:
# Loss=1.10 Batch_ID=781 Accuracy=62.68: 100%|██████████| 782/782 [01:00<00:00, 12.99it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0130, Accuracy: 7080/10000 (70.80%)
#
# Epoch 3:
# Loss=1.34 Batch_ID=781 Accuracy=69.78: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0121, Accuracy: 7299/10000 (72.99%)
#
# Epoch 4:
# Loss=0.55 Batch_ID=781 Accuracy=73.81: 100%|██████████| 782/782 [00:59<00:00, 13.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0096, Accuracy: 7932/10000 (79.32%)
#
# Epoch 5:
# Loss=1.72 Batch_ID=781 Accuracy=76.71: 100%|██████████| 782/782 [00:59<00:00, 13.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0087, Accuracy: 8098/10000 (80.98%)
#
# Epoch 6:
# Loss=0.35 Batch_ID=781 Accuracy=78.79: 100%|██████████| 782/782 [01:00<00:00, 12.95it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0085, Accuracy: 8145/10000 (81.45%)
#
# Epoch 7:
# Loss=0.74 Batch_ID=781 Accuracy=80.57: 100%|██████████| 782/782 [01:00<00:00, 12.92it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0074, Accuracy: 8402/10000 (84.02%)
#
# Epoch 8:
# Loss=0.76 Batch_ID=781 Accuracy=82.04: 100%|██████████| 782/782 [01:00<00:00, 12.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0077, Accuracy: 8342/10000 (83.42%)
#
# Epoch 9:
# Loss=0.81 Batch_ID=781 Accuracy=83.24: 100%|██████████| 782/782 [01:00<00:00, 12.90it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0070, Accuracy: 8538/10000 (85.38%)
#
# Epoch 10:
# Loss=0.23 Batch_ID=781 Accuracy=84.41: 100%|██████████| 782/782 [01:00<00:00, 12.87it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0069, Accuracy: 8529/10000 (85.29%)
#
# Epoch 11:
# Loss=0.32 Batch_ID=781 Accuracy=85.22: 100%|██████████| 782/782 [00:59<00:00, 13.08it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8643/10000 (86.43%)
#
# Epoch 12:
# Loss=0.60 Batch_ID=781 Accuracy=86.18: 100%|██████████| 782/782 [01:00<00:00, 12.91it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8657/10000 (86.57%)
#
# Epoch 13:
# Loss=0.43 Batch_ID=781 Accuracy=86.87: 100%|██████████| 782/782 [01:00<00:00, 12.76it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0067, Accuracy: 8632/10000 (86.32%)
#
# Epoch 14:
# Loss=1.21 Batch_ID=781 Accuracy=87.62: 100%|██████████| 782/782 [01:00<00:00, 12.90it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0065, Accuracy: 8666/10000 (86.66%)
#
# Epoch 15:
# Loss=0.32 Batch_ID=781 Accuracy=88.54: 100%|██████████| 782/782 [01:00<00:00, 12.91it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8692/10000 (86.92%)
#
# Epoch 16:
# Loss=0.24 Batch_ID=781 Accuracy=88.82: 100%|██████████| 782/782 [01:00<00:00, 12.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0074, Accuracy: 8524/10000 (85.24%)
#
# Epoch 17:
# Loss=1.07 Batch_ID=781 Accuracy=89.88: 100%|██████████| 782/782 [01:00<00:00, 13.02it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8658/10000 (86.58%)
#
# Epoch 18:
# Loss=0.48 Batch_ID=781 Accuracy=90.07: 100%|██████████| 782/782 [00:59<00:00, 13.06it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0058, Accuracy: 8797/10000 (87.97%)
#
# Epoch 19:
# Loss=0.07 Batch_ID=781 Accuracy=90.56: 100%|██████████| 782/782 [00:59<00:00, 13.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0058, Accuracy: 8813/10000 (88.13%)
#
# Epoch 20:
# Loss=0.04 Batch_ID=781 Accuracy=90.91: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0061, Accuracy: 8773/10000 (87.73%)
#
# Epoch 21:
# Loss=0.19 Batch_ID=781 Accuracy=91.31: 100%|██████████| 782/782 [00:59<00:00, 13.08it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8699/10000 (86.99%)
#
# Epoch 22:
# Loss=0.05 Batch_ID=781 Accuracy=91.74: 100%|██████████| 782/782 [00:59<00:00, 13.06it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0065, Accuracy: 8712/10000 (87.12%)
#
# Epoch 23:
# Loss=0.39 Batch_ID=781 Accuracy=91.83: 100%|██████████| 782/782 [00:59<00:00, 13.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8744/10000 (87.44%)
#
# Epoch 24:
# Loss=0.39 Batch_ID=781 Accuracy=92.34: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0058, Accuracy: 8854/10000 (88.54%)
#
# Epoch 25:
# Loss=0.12 Batch_ID=781 Accuracy=92.45: 100%|██████████| 782/782 [00:59<00:00, 13.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8886/10000 (88.86%)
#
# Epoch 26:
# Loss=0.21 Batch_ID=781 Accuracy=92.97: 100%|██████████| 782/782 [01:00<00:00, 13.03it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0056, Accuracy: 8887/10000 (88.87%)
#
# Epoch 27:
# Loss=0.89 Batch_ID=781 Accuracy=92.99: 100%|██████████| 782/782 [00:59<00:00, 13.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0061, Accuracy: 8831/10000 (88.31%)
#
# Epoch 28:
# Loss=0.17 Batch_ID=781 Accuracy=93.15: 100%|██████████| 782/782 [01:00<00:00, 13.00it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0056, Accuracy: 8920/10000 (89.20%)
#
# Epoch 29:
# Loss=0.19 Batch_ID=781 Accuracy=93.49: 100%|██████████| 782/782 [01:00<00:00, 12.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0055, Accuracy: 8974/10000 (89.74%)
#
# Epoch 30:
# Loss=0.22 Batch_ID=781 Accuracy=93.64: 100%|██████████| 782/782 [01:00<00:00, 12.96it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8938/10000 (89.38%)
#
# Epoch 31:
# Loss=0.13 Batch_ID=781 Accuracy=93.96: 100%|██████████| 782/782 [01:00<00:00, 12.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8971/10000 (89.71%)
#
# Epoch 32:
# Loss=0.48 Batch_ID=781 Accuracy=94.11: 100%|██████████| 782/782 [00:59<00:00, 13.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8835/10000 (88.35%)
#
# Epoch 33:
# Loss=0.13 Batch_ID=781 Accuracy=94.34: 100%|██████████| 782/782 [00:59<00:00, 13.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8969/10000 (89.69%)
#
# Epoch 34:
# Loss=0.18 Batch_ID=781 Accuracy=94.42: 100%|██████████| 782/782 [00:59<00:00, 13.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0056, Accuracy: 8945/10000 (89.45%)
#
# Epoch 35:
# Loss=0.20 Batch_ID=781 Accuracy=94.45: 100%|██████████| 782/782 [00:59<00:00, 13.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8955/10000 (89.55%)
#
# Epoch 36:
# Loss=0.07 Batch_ID=781 Accuracy=94.60: 100%|██████████| 782/782 [00:59<00:00, 13.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0053, Accuracy: 8992/10000 (89.92%)
#
# Epoch 37:
# Loss=0.58 Batch_ID=781 Accuracy=94.74: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0059, Accuracy: 8949/10000 (89.49%)
#
# Epoch 38:
# Loss=0.18 Batch_ID=781 Accuracy=95.06: 100%|██████████| 782/782 [00:59<00:00, 13.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0053, Accuracy: 8989/10000 (89.89%)
#
# Epoch 39:
# Loss=0.02 Batch_ID=781 Accuracy=95.09: 100%|██████████| 782/782 [00:59<00:00, 13.08it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0053, Accuracy: 8985/10000 (89.85%)
#
# Epoch 40:
# Loss=0.04 Batch_ID=781 Accuracy=94.99: 100%|██████████| 782/782 [00:59<00:00, 13.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0055, Accuracy: 9011/10000 (90.11%)
#
# Epoch 41:
# Loss=0.24 Batch_ID=781 Accuracy=95.28: 100%|██████████| 782/782 [00:59<00:00, 13.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8972/10000 (89.72%)
#
# Epoch 42:
# Loss=0.07 Batch_ID=781 Accuracy=95.54: 100%|██████████| 782/782 [00:59<00:00, 13.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 8982/10000 (89.82%)
#
# Epoch 43:
# Loss=0.07 Batch_ID=781 Accuracy=95.35: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0053, Accuracy: 9050/10000 (90.50%)
#
# Epoch 44:
# Loss=0.13 Batch_ID=781 Accuracy=95.59: 100%|██████████| 782/782 [00:59<00:00, 13.10it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0058, Accuracy: 9010/10000 (90.10%)
#
# Epoch 45:
# Loss=0.23 Batch_ID=781 Accuracy=95.43: 100%|██████████| 782/782 [00:59<00:00, 13.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0054, Accuracy: 9029/10000 (90.29%)
#
# Epoch 46:
# Loss=0.02 Batch_ID=781 Accuracy=95.74: 100%|██████████| 782/782 [00:59<00:00, 13.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0057, Accuracy: 9004/10000 (90.04%)
#
# Epoch 47:
# Loss=0.07 Batch_ID=781 Accuracy=95.78: 100%|██████████| 782/782 [00:59<00:00, 13.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0054, Accuracy: 9051/10000 (90.51%)
#
# Epoch 48:
# Loss=0.15 Batch_ID=781 Accuracy=95.82: 100%|██████████| 782/782 [01:00<00:00, 13.01it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0056, Accuracy: 9044/10000 (90.44%)
#
# Epoch 49:
# Loss=0.14 Batch_ID=781 Accuracy=96.05: 100%|██████████| 782/782 [01:00<00:00, 12.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0056, Accuracy: 9026/10000 (90.26%)
#
# Epoch 50:
# Loss=0.31 Batch_ID=781 Accuracy=95.78: 100%|██████████| 782/782 [01:00<00:00, 12.97it/s]
# Validation set: Average loss: 0.0056, Accuracy: 8988/10000 (89.88%)

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# Plot changes in validation loss

# %%
plot_metric(losses, 'Loss')

# %% [markdown]
# Plot changes in validation accuracy

# %%
plot_metric(accuracies, 'Accuracy')

# %% [markdown]
# ## Display Incorrect Predictions

# %%
save_and_show_result(correct_samples, incorrect_samples, classes)

# %% [markdown]
# ## Result Analysis
#
# Displaying accuracy for each class in the entire validation dataset

# %%
class_level_accuracy(model, val_loader, device, classes)
# Out:
# Accuracy of plane : 93 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 89 %
# Accuracy of   cat : 80 %
# Accuracy of  deer : 86 %
# Accuracy of   dog : 81 %
# Accuracy of  frog : 91 %
# Accuracy of horse : 92 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 94 %
