# %% [markdown]
# # Installing Packages

# %%
# !pip install --no-cache-dir -r requirements.txt

# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import random
import matplotlib.pyplot as plt

from tensornet.data.datasets import TinyImageNet
from tensornet.model import ResNet18
from tensornet.model.utils.loss import cross_entropy_loss
from tensornet.model.utils.optimizers import sgd
from tensornet.engine.ops.lr_scheduler import reduce_lr_on_plateau
from tensornet.utils import initialize_cuda, plot_metric

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(1)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the TinyImagenet class to download dataset and create data loader

# %%
dataset = TinyImageNet(
    train_batch_size=128,
    val_batch_size=128,
    cuda=cuda,
    num_workers=16,
    horizontal_flip_prob=0.3,
    vertical_flip_prob=0.1,
    rotate_degree=10,
    cutout_prob=0.3,
    cutout_dim=(16, 16),
)
# Out:
# Files already downloaded.
# Files already downloaded.
# Files already downloaded.

# %% [markdown]
# ## Data Visualization

# %%
# Fetch data
classes = dataset.classes

# Set number of images to display
num_images = 4

# Display images with labels
fig, axs = plt.subplots(1, 4, figsize=(8, 8))
fig.tight_layout()

for i in range(num_images):
    idx = random.randint(0, len(dataset.val_data))
    axs[i].axis('off')
    axs[i].set_title(f'Label: {classes[dataset.val_data[idx][1]].split(",")[0]}')
    axs[i].imshow(dataset.unnormalize(dataset.val_data[idx][0], transpose=True))

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18(num_classes=len(dataset.classes)).to(device)
model.summary(dataset.image_size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 64, 64]           1,728
#        BatchNorm2d-2           [-1, 64, 64, 64]             128
#             Conv2d-3           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-4           [-1, 64, 64, 64]             128
#             Conv2d-5           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#         BasicBlock-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#            Conv2d-10           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-11           [-1, 64, 64, 64]             128
#        BasicBlock-12           [-1, 64, 64, 64]               0
#            Conv2d-13          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-14          [-1, 128, 32, 32]             256
#            Conv2d-15          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-16          [-1, 128, 32, 32]             256
#            Conv2d-17          [-1, 128, 32, 32]           8,192
#       BatchNorm2d-18          [-1, 128, 32, 32]             256
#        BasicBlock-19          [-1, 128, 32, 32]               0
#            Conv2d-20          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-21          [-1, 128, 32, 32]             256
#            Conv2d-22          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-23          [-1, 128, 32, 32]             256
#        BasicBlock-24          [-1, 128, 32, 32]               0
#            Conv2d-25          [-1, 256, 16, 16]         294,912
#       BatchNorm2d-26          [-1, 256, 16, 16]             512
#            Conv2d-27          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-28          [-1, 256, 16, 16]             512
#            Conv2d-29          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-30          [-1, 256, 16, 16]             512
#        BasicBlock-31          [-1, 256, 16, 16]               0
#            Conv2d-32          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-33          [-1, 256, 16, 16]             512
#            Conv2d-34          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-35          [-1, 256, 16, 16]             512
#        BasicBlock-36          [-1, 256, 16, 16]               0
#            Conv2d-37            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-38            [-1, 512, 8, 8]           1,024
#            Conv2d-39            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-40            [-1, 512, 8, 8]           1,024
#            Conv2d-41            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-42            [-1, 512, 8, 8]           1,024
#        BasicBlock-43            [-1, 512, 8, 8]               0
#            Conv2d-44            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-45            [-1, 512, 8, 8]           1,024
#            Conv2d-46            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-47            [-1, 512, 8, 8]           1,024
#        BasicBlock-48            [-1, 512, 8, 8]               0
# AdaptiveAvgPool2d-49            [-1, 512, 1, 1]               0
#            Linear-50                  [-1, 200]         102,600
# ================================================================
# Total params: 11,271,432
# Trainable params: 11,271,432
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 45.01
# Params size (MB): 43.00
# Estimated Total Size (MB): 88.05
# ----------------------------------------------------------------

# %% [markdown]
# # Model Training and Validation

# %%
optimizer = sgd(model, learning_rate=0.01, momentum=0.9)  # Create optimizer
criterion = cross_entropy_loss()  # Create loss function

# %%
epochs = 50

# Setup Reduce LR on Plateau
scheduler = reduce_lr_on_plateau(optimizer, patience=2, verbose=True, min_lr=1e-6)

# Model Training
model.fit(
    train_loader, optimizer, criterion, device=device, epochs=epochs,
    val_loader=val_loader, callbacks=[scheduler]
)
# Out:
# Epoch 1:
# 602/602 [========] - 149s 247ms/step - loss: 4.4573 - accuracy: 4.7045
# Validation set: Average loss: 0.0331, Accuracy: 11.21%
#
# Epoch 2:
# 602/602 [========] - 148s 247ms/step - loss: 3.6814 - accuracy: 10.5993
# Validation set: Average loss: 0.0295, Accuracy: 16.54%
#
# Epoch 3:
# 602/602 [========] - 148s 246ms/step - loss: 3.2787 - accuracy: 14.9748
# Validation set: Average loss: 0.0278, Accuracy: 20.88%
#
# Epoch 4:
# 602/602 [========] - 148s 246ms/step - loss: 2.9940 - accuracy: 18.5150
# Validation set: Average loss: 0.0251, Accuracy: 27.20%
#
# Epoch 5:
# 602/602 [========] - 148s 246ms/step - loss: 2.7735 - accuracy: 21.4928
# Validation set: Average loss: 0.0221, Accuracy: 33.30%
#
# Epoch 6:
# 602/602 [========] - 148s 245ms/step - loss: 2.5921 - accuracy: 24.1308
# Validation set: Average loss: 0.0211, Accuracy: 35.80%
#
# Epoch 7:
# 602/602 [========] - 148s 246ms/step - loss: 2.4434 - accuracy: 26.4772
# Validation set: Average loss: 0.0210, Accuracy: 37.10%
#
# Epoch 8:
# 602/602 [========] - 148s 246ms/step - loss: 2.3087 - accuracy: 28.5611
# Validation set: Average loss: 0.0214, Accuracy: 36.38%
#
# Epoch 9:
# 602/602 [========] - 148s 246ms/step - loss: 2.1871 - accuracy: 30.4464
# Validation set: Average loss: 0.0186, Accuracy: 42.92%
#
# Epoch 10:
# 602/602 [========] - 148s 246ms/step - loss: 2.0793 - accuracy: 32.1968
# Validation set: Average loss: 0.0193, Accuracy: 41.51%
#
# Epoch 11:
# 602/602 [========] - 148s 246ms/step - loss: 1.9801 - accuracy: 33.8205
# Validation set: Average loss: 0.0198, Accuracy: 41.33%
#
# Epoch 12:
# 602/602 [========] - 149s 247ms/step - loss: 1.8828 - accuracy: 35.3500
# Validation set: Average loss: 0.0189, Accuracy: 43.06%
#
# Epoch    12: reducing learning rate of group 0 to 1.0000e-03.
# Epoch
# Validation set: Average loss: 0.0143, Accuracy: 55.36%
#
# Epoch 32:
# 602/602 [========] - 149s 247ms/step - loss: 1.0011 - accuracy: 56.6004
# Validation set: Average loss: 0.0143, Accuracy: 55.34%
#
# Epoch 33:
# 602/602 [========] - 149s 247ms/step - loss: 0.9956 - accuracy: 57.1813
# Validation set: Average loss: 0.0143, Accuracy: 55.34%
#
# Epoch 34:
# 602/602 [========] - 148s 247ms/step - loss: 0.9877 - accuracy: 57.7291
# Validation set: Average loss: 0.0143, Accuracy: 55.35%
#
# Epoch 35:
# 602/602 [========] - 148s 247ms/step - loss: 0.9905 - accuracy: 58.2484
# Validation set: Average loss: 0.0143, Accuracy: 55.30%
#
# Epoch    35: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 36:
# 602/602 [========] - 148s 246ms/step - loss: 0.9816 - accuracy: 58.7375
# Validation set: Average loss: 0.0143, Accuracy: 55.26%
#
# Epoch 37:
# 602/602 [========] - 148s 246ms/step - loss: 0.9768 - accuracy: 59.2100
# Validation set: Average loss: 0.0143, Accuracy: 55.37%
#
# Epoch 38:
# 602/602 [========] - 148s 246ms/step - loss: 0.9748 - accuracy: 59.6557
# Validation set: Average loss: 0.0143, Accuracy: 55.31%
#
# Epoch 39:
# 602/602 [========] - 148s 246ms/step - loss: 0.9760 - accuracy: 60.0803
# Validation set: Average loss: 0.0143, Accuracy: 55.35%
#
# Epoch 40:
# 602/602 [========] - 148s 246ms/step - loss: 0.9816 - accuracy: 60.4804
# Validation set: Average loss: 0.0143, Accuracy: 55.28%
#
# Epoch    40: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 41:
# 602/602 [========] - 148s 246ms/step - loss: 0.9782 - accuracy: 60.8632
# Validation set: Average loss: 0.0143, Accuracy: 55.35%
#
# Epoch 42:
# 602/602 [========] - 148s 246ms/step - loss: 0.9785 - accuracy: 61.2288
# Validation set: Average loss: 0.0143, Accuracy: 55.33%
#
# Epoch 43:
# 602/602 [========] - 148s 246ms/step - loss: 0.9821 - accuracy: 61.5730
# Validation set: Average loss: 0.0143, Accuracy: 55.39%
#
# Epoch 44:
# 602/602 [========] - 148s 246ms/step - loss: 0.9742 - accuracy: 61.9053
# Validation set: Average loss: 0.0143, Accuracy: 55.33%
#
# Epoch 45:
# 602/602 [========] - 148s 247ms/step - loss: 0.9775 - accuracy: 62.2206
# Validation set: Average loss: 0.0143, Accuracy: 55.42%
#
# Epoch 46:
# 602/602 [========] - 148s 246ms/step - loss: 0.9771 - accuracy: 62.5191
# Validation set: Average loss: 0.0143, Accuracy: 55.36%
#
# Epoch 47:
# 602/602 [========] - 148s 246ms/step - loss: 0.9772 - accuracy: 62.8079
# Validation set: Average loss: 0.0143, Accuracy: 55.31%
#
# Epoch 48:
# 602/602 [========] - 148s 246ms/step - loss: 0.9740 - accuracy: 63.0871
# Validation set: Average loss: 0.0143, Accuracy: 55.31%
#
# Epoch 49:
# 602/602 [========] - 148s 247ms/step - loss: 0.9743 - accuracy: 63.3537
# Validation set: Average loss: 0.0143, Accuracy: 55.31%
#
# Epoch 50:
# 602/602 [========] - 149s 247ms/step - loss: 0.9750 - accuracy: 63.6093
# Validation set: Average loss: 0.0143, Accuracy: 55.38%

# %% [markdown]
# # Plotting Results
#
# Plot changes in validation accuracy

# %%
plot_metric({
    'Training': model.learner.train_accuracies,
    'Validation': model.learner.val_accuracies
}, 'Accuracy')
