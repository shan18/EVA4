# %% [markdown]
# # Installing Packages

# %%
# !pip install albumentations==0.4.5

# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import random

from torchsummary import summary

from cuda import initialize_cuda
from data.dataset import CIFAR10
from model import ResNet18
from model.utils.loss import cross_entropy_loss
from model.utils.optimizers import sgd_optimizer
from model.utils.callbacks import lr_scheduler
from gradcam import GradCAMView
from train import train
from evaluate import val
from result import plot_metric, save_and_show_result

# %% [markdown]
# # Configuration
#
# Set various parameters and hyperparameters

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Augmentation
    # ============
    horizontal_flip_prob = 0.2
    vertical_flip_prob = 0.0
    gaussian_blur_prob = 0.0
    rotate_degree = 20
    cutout = 0.3

    # Training
    # ========
    random_seed = 1
    epochs = 50
    learning_rate = 0.01
    momentum = 0.9
    lr_step_size = 25
    lr_gamma = 0.1

    # Evaluation
    # ==========
    sample_count = 25

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the CIFAR-10 class to download dataset and create data loader

# %%
dataset = CIFAR10(
    train_batch_size=Args.train_batch_size,
    val_batch_size=Args.val_batch_size,
    cuda=cuda,
    num_workers=Args.num_workers,
    horizontal_flip_prob=Args.horizontal_flip_prob,
    vertical_flip_prob=Args.vertical_flip_prob,
    gaussian_blur_prob=Args.gaussian_blur_prob,
    rotate_degree=Args.rotate_degree,
    cutout=Args.cutout
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18().to(device)  # Create model
summary(model, dataset.image_size)  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Model Training and Validation

# %%
losses = []
accuracies = []
correct_samples = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd_optimizer(model, Args.learning_rate, Args.momentum)  # Create optimizer
scheduler = lr_scheduler(optimizer, Args.lr_step_size, Args.lr_gamma)
last_epoch = False

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    if epoch == Args.epochs:
        last_epoch = True
    train(model, train_loader, device, optimizer, criterion)
    scheduler.step()
    val(
        model, val_loader, device, criterion, losses, accuracies,
        correct_samples, incorrect_samples, Args.sample_count, last_epoch=last_epoch
    )
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=1.02 Batch_ID=781 Accuracy=50.10: 100%|██████████| 782/782 [00:58<00:00, 13.47it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0140, Accuracy: 6795/10000 (67.95%)
#
# Epoch 2:
# Loss=0.92 Batch_ID=781 Accuracy=68.97: 100%|██████████| 782/782 [00:58<00:00, 13.27it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0129, Accuracy: 7152/10000 (71.52%)
#
# Epoch 3:
# Loss=1.32 Batch_ID=781 Accuracy=75.82: 100%|██████████| 782/782 [00:58<00:00, 13.32it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0102, Accuracy: 7736/10000 (77.36%)
#
# Epoch 4:
# Loss=0.59 Batch_ID=781 Accuracy=79.31: 100%|██████████| 782/782 [00:59<00:00, 13.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0104, Accuracy: 7806/10000 (78.06%)
#
# Epoch 5:
# Loss=0.96 Batch_ID=781 Accuracy=81.92: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0085, Accuracy: 8132/10000 (81.32%)
#
# Epoch 6:
# Loss=0.37 Batch_ID=781 Accuracy=84.31: 100%|██████████| 782/782 [00:58<00:00, 13.28it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0078, Accuracy: 8332/10000 (83.32%)
#
# Epoch 7:
# Loss=0.27 Batch_ID=781 Accuracy=85.67: 100%|██████████| 782/782 [00:59<00:00, 13.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0075, Accuracy: 8393/10000 (83.93%)
#
# Epoch 8:
# Loss=0.21 Batch_ID=781 Accuracy=86.96: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0082, Accuracy: 8321/10000 (83.21%)
#
# Epoch 9:
# Loss=0.70 Batch_ID=781 Accuracy=87.98: 100%|██████████| 782/782 [00:59<00:00, 13.25it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0070, Accuracy: 8508/10000 (85.08%)
#
# Epoch 10:
# Loss=0.38 Batch_ID=781 Accuracy=89.26: 100%|██████████| 782/782 [00:59<00:00, 13.14it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0068, Accuracy: 8582/10000 (85.82%)
#
# Epoch 11:
# Loss=0.30 Batch_ID=781 Accuracy=90.01: 100%|██████████| 782/782 [00:58<00:00, 13.34it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8670/10000 (86.70%)
#
# Epoch 12:
# Loss=0.43 Batch_ID=781 Accuracy=90.79: 100%|██████████| 782/782 [00:58<00:00, 13.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0070, Accuracy: 8569/10000 (85.69%)
#
# Epoch 13:
# Loss=0.13 Batch_ID=781 Accuracy=91.83: 100%|██████████| 782/782 [00:59<00:00, 13.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0075, Accuracy: 8542/10000 (85.42%)
#
# Epoch 14:
# Loss=0.44 Batch_ID=781 Accuracy=92.26: 100%|██████████| 782/782 [00:59<00:00, 13.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0065, Accuracy: 8738/10000 (87.38%)
#
# Epoch 15:
# Loss=0.47 Batch_ID=781 Accuracy=92.75: 100%|██████████| 782/782 [00:58<00:00, 13.28it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0068, Accuracy: 8724/10000 (87.24%)
#
# Epoch 16:
# Loss=0.06 Batch_ID=781 Accuracy=93.11: 100%|██████████| 782/782 [00:59<00:00, 13.21it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8756/10000 (87.56%)
#
# Epoch 17:
# Loss=0.17 Batch_ID=781 Accuracy=93.60: 100%|██████████| 782/782 [00:58<00:00, 13.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8757/10000 (87.57%)
#
# Epoch 18:
# Loss=0.35 Batch_ID=781 Accuracy=94.12: 100%|██████████| 782/782 [00:59<00:00, 13.10it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8756/10000 (87.56%)
#
# Epoch 19:
# Loss=0.01 Batch_ID=781 Accuracy=94.52: 100%|██████████| 782/782 [00:58<00:00, 13.28it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8822/10000 (88.22%)
#
# Epoch 20:
# Loss=0.00 Batch_ID=781 Accuracy=94.93: 100%|██████████| 782/782 [00:59<00:00, 13.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8810/10000 (88.10%)
#
# Epoch 21:
# Loss=0.05 Batch_ID=781 Accuracy=95.12: 100%|██████████| 782/782 [00:58<00:00, 13.38it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0059, Accuracy: 8883/10000 (88.83%)
#
# Epoch 22:
# Loss=0.27 Batch_ID=781 Accuracy=95.31: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8774/10000 (87.74%)
#
# Epoch 23:
# Loss=0.56 Batch_ID=781 Accuracy=95.64: 100%|██████████| 782/782 [00:59<00:00, 13.25it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0065, Accuracy: 8857/10000 (88.57%)
#
# Epoch 24:
# Loss=0.04 Batch_ID=781 Accuracy=95.56: 100%|██████████| 782/782 [00:58<00:00, 13.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0065, Accuracy: 8870/10000 (88.70%)
#
# Epoch 25:
# Loss=0.04 Batch_ID=781 Accuracy=95.76: 100%|██████████| 782/782 [00:59<00:00, 13.24it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0061, Accuracy: 8864/10000 (88.64%)
#
# Epoch 26:
# Loss=0.27 Batch_ID=781 Accuracy=97.23: 100%|██████████| 782/782 [00:59<00:00, 13.20it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9057/10000 (90.57%)
#
# Epoch 27:
# Loss=0.77 Batch_ID=781 Accuracy=97.78: 100%|██████████| 782/782 [00:59<00:00, 13.23it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9068/10000 (90.68%)
#
# Epoch 28:
# Loss=0.08 Batch_ID=781 Accuracy=97.89: 100%|██████████| 782/782 [00:58<00:00, 13.29it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9097/10000 (90.97%)
#
# Epoch 29:
# Loss=0.05 Batch_ID=781 Accuracy=98.10: 100%|██████████| 782/782 [00:58<00:00, 13.32it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9111/10000 (91.11%)
#
# Epoch 30:
# Loss=0.04 Batch_ID=781 Accuracy=98.09: 100%|██████████| 782/782 [00:59<00:00, 13.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9111/10000 (91.11%)
#
# Epoch 31:
# Loss=0.29 Batch_ID=781 Accuracy=98.31: 100%|██████████| 782/782 [00:59<00:00, 13.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9110/10000 (91.10%)
#
# Epoch 32:
# Loss=0.25 Batch_ID=781 Accuracy=98.36: 100%|██████████| 782/782 [00:59<00:00, 13.20it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9120/10000 (91.20%)
#
# Epoch 33:
# Loss=0.03 Batch_ID=781 Accuracy=98.29: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9130/10000 (91.30%)
#
# Epoch 34:
# Loss=0.53 Batch_ID=781 Accuracy=98.38: 100%|██████████| 782/782 [00:59<00:00, 13.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9121/10000 (91.21%)
#
# Epoch 35:
# Loss=0.03 Batch_ID=781 Accuracy=98.47: 100%|██████████| 782/782 [00:59<00:00, 13.23it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9119/10000 (91.19%)
#
# Epoch 36:
# Loss=0.09 Batch_ID=781 Accuracy=98.49: 100%|██████████| 782/782 [00:59<00:00, 13.23it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9128/10000 (91.28%)
#
# Epoch 37:
# Loss=0.03 Batch_ID=781 Accuracy=98.51: 100%|██████████| 782/782 [00:59<00:00, 13.21it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9139/10000 (91.39%)
#
# Epoch 38:
# Loss=0.01 Batch_ID=781 Accuracy=98.48: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9137/10000 (91.37%)
#
# Epoch 39:
# Loss=0.00 Batch_ID=781 Accuracy=98.56: 100%|██████████| 782/782 [00:58<00:00, 13.29it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9125/10000 (91.25%)
#
# Epoch 40:
# Loss=0.00 Batch_ID=781 Accuracy=98.58: 100%|██████████| 782/782 [00:59<00:00, 13.14it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9138/10000 (91.38%)
#
# Epoch 41:
# Loss=0.01 Batch_ID=781 Accuracy=98.72: 100%|██████████| 782/782 [00:58<00:00, 13.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9153/10000 (91.53%)
#
# Epoch 42:
# Loss=0.02 Batch_ID=781 Accuracy=98.64: 100%|██████████| 782/782 [00:58<00:00, 13.28it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9129/10000 (91.29%)
#
# Epoch 43:
# Loss=0.02 Batch_ID=781 Accuracy=98.63: 100%|██████████| 782/782 [00:58<00:00, 13.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9124/10000 (91.24%)
#
# Epoch 44:
# Loss=0.01 Batch_ID=781 Accuracy=98.69: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9134/10000 (91.34%)
#
# Epoch 45:
# Loss=0.00 Batch_ID=781 Accuracy=98.79: 100%|██████████| 782/782 [00:58<00:00, 13.26it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9139/10000 (91.39%)
#
# Epoch 46:
# Loss=0.05 Batch_ID=781 Accuracy=98.70: 100%|██████████| 782/782 [00:58<00:00, 13.27it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9121/10000 (91.21%)
#
# Epoch 47:
# Loss=0.25 Batch_ID=781 Accuracy=98.76: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9131/10000 (91.31%)
#
# Epoch 48:
# Loss=0.00 Batch_ID=781 Accuracy=98.82: 100%|██████████| 782/782 [00:59<00:00, 13.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9123/10000 (91.23%)
#
# Epoch 49:
# Loss=0.10 Batch_ID=781 Accuracy=98.85: 100%|██████████| 782/782 [00:59<00:00, 13.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0052, Accuracy: 9135/10000 (91.35%)
#
# Epoch 50:
# Loss=0.00 Batch_ID=781 Accuracy=98.84: 100%|██████████| 782/782 [00:59<00:00, 13.24it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9123/10000 (91.23%)

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# Plot changes in validation loss

# %%
plot_metric(losses, 'Loss')

# %% [markdown]
# Plot changes in validation accuracy

# %%
plot_metric(accuracies, 'Accuracy')

# %% [markdown]
# ### GradCAM

# %% [markdown]
# Let's display GradCAM of any random 2 correctly predicted samples

# %%
grad_cam = GradCAMView(
    model, ['layer1', 'layer2', 'layer3', 'layer4'],
    device, dataset.mean, dataset.std
)

images = [x['image'] for x in random.sample(correct_samples, 4)]
grad_cam(images, 'grad_cam')
# Out:
# Mode set to GradCAM.
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2416: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Display Correct and Incorrect Predictions

# %%
save_and_show_result(correct_samples, incorrect_samples, dataset.classes)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
