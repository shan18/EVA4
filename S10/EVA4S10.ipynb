# %% [markdown]
# # Installing Packages

# %%
# !pip install --no-cache-dir torch-tensornet==0.0.7 torchsummary==1.5.1

# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

from torchsummary import summary
from tensornet import train, evaluate
from tensornet.data import CIFAR10
from tensornet.model import ResNet18
from tensornet.model.utils import LRFinder
from tensornet.model.utils.loss import cross_entropy_loss
from tensornet.model.utils.optimizers import sgd
from tensornet.model.utils.callbacks import reduce_lr_on_plateau
from tensornet.gradcam import GradCAMView
from tensornet.utils import initialize_cuda, plot_metric, class_level_accuracy

# %% [markdown]
# # Configuration
#
# Set various parameters and hyperparameters

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Augmentation
    # ============
    horizontal_flip_prob = 0.2
    rotate_degree = 20
    cutout = 0.3

    # Training
    # ========
    random_seed = 1
    epochs = 50
    momentum = 0.9
    start_lr = 1e-7
    end_lr = 5
    num_iter = 400
    min_lr = 1e-4
    lr_decay_factor = 0.1
    lr_decay_patience = 2

    # Evaluation
    # ==========
    sample_count = 25

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the CIFAR-10 class to download dataset and create data loader

# %%
dataset = CIFAR10(
    train_batch_size=Args.train_batch_size,
    val_batch_size=Args.val_batch_size,
    cuda=cuda,
    num_workers=Args.num_workers,
    horizontal_flip_prob=Args.horizontal_flip_prob,
    rotate_degree=Args.rotate_degree,
    cutout=Args.cutout
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18().to(device)  # Create model
summary(model, dataset.image_size)  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Find Initial Learning Rate

# %%
model = ResNet18().to(device)  # Create model
optimizer = sgd(model, Args.start_lr, Args.momentum)  # Create optimizer
criterion = cross_entropy_loss()  # Create loss function

# Find learning rate
lr_finder = LRFinder(model, optimizer, criterion, device=device)
lr_finder.range_test(train_loader, end_lr=Args.end_lr, num_iter=Args.num_iter, step_mode='exp')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Learning rate search finished.

# %%
# Get best initial learning rate
initial_lr = lr_finder.best_lr

# Print learning rate and loss
print('Learning Rate:', initial_lr)
print('Loss:', lr_finder.best_loss)

# Plot learning rate vs loss
lr_finder.plot()

# Reset graph
lr_finder.reset()
# Out:
# Learning Rate: 0.012059247341566626
# Loss: 1.8264832157316113

# %% [markdown]
# # Model Training and Validation

# %%
train_accuracies = []
val_losses = []
val_accuracies = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd(model, initial_lr, Args.momentum)  # Create optimizer
scheduler = reduce_lr_on_plateau(  # Define Reduce LR on plateau
    optimizer, factor=Args.lr_decay_factor,
    patience=Args.lr_decay_patience, verbose=True,
    min_lr=Args.min_lr
)
last_epoch = False

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    if epoch == Args.epochs:
        last_epoch = True
    train(model, train_loader, device, optimizer, criterion, accuracies=train_accuracies)
    evaluate(
        model, val_loader, device, criterion, losses=val_losses,
        accuracies=val_accuracies, incorrect_samples=incorrect_samples,
        sample_count=Args.sample_count, last_epoch=last_epoch
    )
    scheduler.step(val_losses[-1])
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=0.98 Batch_ID=781 Accuracy=49.63: 100%|██████████| 782/782 [00:29<00:00, 26.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0174, Accuracy: 6093/10000 (60.93%)
#
# Epoch 2:
# Loss=0.86 Batch_ID=781 Accuracy=67.90: 100%|██████████| 782/782 [00:29<00:00, 26.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0129, Accuracy: 7145/10000 (71.45%)
#
# Epoch 3:
# Loss=0.56 Batch_ID=781 Accuracy=75.03: 100%|██████████| 782/782 [00:29<00:00, 26.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0110, Accuracy: 7554/10000 (75.54%)
#
# Epoch 4:
# Loss=0.38 Batch_ID=781 Accuracy=78.88: 100%|██████████| 782/782 [00:29<00:00, 26.52it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0088, Accuracy: 8079/10000 (80.79%)
#
# Epoch 5:
# Loss=0.94 Batch_ID=781 Accuracy=81.43: 100%|██████████| 782/782 [00:29<00:00, 26.23it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0090, Accuracy: 8121/10000 (81.21%)
#
# Epoch 6:
# Loss=0.62 Batch_ID=781 Accuracy=83.71: 100%|██████████| 782/782 [00:29<00:00, 26.25it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0085, Accuracy: 8233/10000 (82.33%)
#
# Epoch 7:
# Loss=0.37 Batch_ID=781 Accuracy=85.46: 100%|██████████| 782/782 [00:29<00:00, 26.34it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0074, Accuracy: 8373/10000 (83.73%)
#
# Epoch 8:
# Loss=1.03 Batch_ID=781 Accuracy=86.89: 100%|██████████| 782/782 [00:29<00:00, 26.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0075, Accuracy: 8372/10000 (83.72%)
#
# Epoch 9:
# Loss=0.50 Batch_ID=781 Accuracy=88.41: 100%|██████████| 782/782 [00:29<00:00, 26.29it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0074, Accuracy: 8460/10000 (84.60%)
#
# Epoch 10:
# Loss=0.69 Batch_ID=781 Accuracy=89.28: 100%|██████████| 782/782 [00:29<00:00, 26.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0073, Accuracy: 8534/10000 (85.34%)
#
# Epoch 11:
# Loss=0.39 Batch_ID=781 Accuracy=89.80: 100%|██████████| 782/782 [00:29<00:00, 26.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8635/10000 (86.35%)
#
# Epoch 12:
# Loss=0.41 Batch_ID=781 Accuracy=90.86: 100%|██████████| 782/782 [00:29<00:00, 26.23it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0076, Accuracy: 8464/10000 (84.64%)
#
# Epoch 13:
# Loss=0.14 Batch_ID=781 Accuracy=91.65: 100%|██████████| 782/782 [00:29<00:00, 26.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8704/10000 (87.04%)
#
# Epoch 14:
# Loss=0.09 Batch_ID=781 Accuracy=92.30: 100%|██████████| 782/782 [00:29<00:00, 26.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0070, Accuracy: 8692/10000 (86.92%)
#
# Epoch 15:
# Loss=0.17 Batch_ID=781 Accuracy=92.89: 100%|██████████| 782/782 [00:29<00:00, 26.57it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8774/10000 (87.74%)
#
# Epoch 16:
# Loss=0.15 Batch_ID=781 Accuracy=93.16: 100%|██████████| 782/782 [00:29<00:00, 26.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0062, Accuracy: 8791/10000 (87.91%)
#
# Epoch 17:
# Loss=0.16 Batch_ID=781 Accuracy=93.64: 100%|██████████| 782/782 [00:29<00:00, 26.20it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0059, Accuracy: 8879/10000 (88.79%)
#
# Epoch 18:
# Loss=0.33 Batch_ID=781 Accuracy=94.16: 100%|██████████| 782/782 [00:29<00:00, 26.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0062, Accuracy: 8840/10000 (88.40%)
#
# Epoch 19:
# Loss=0.03 Batch_ID=781 Accuracy=94.49: 100%|██████████| 782/782 [00:29<00:00, 26.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8808/10000 (88.08%)
#
# Epoch 20:
# Loss=0.20 Batch_ID=781 Accuracy=94.79: 100%|██████████| 782/782 [00:29<00:00, 26.52it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0060, Accuracy: 8876/10000 (88.76%)
#
# Epoch    20: reducing learning rate of group 0 to 1.2059e-03.
# Epoch 21:
# Loss=0.07 Batch_ID=781 Accuracy=96.65: 100%|██████████| 782/782 [00:29<00:00, 26.14it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9051/10000 (90.51%)
#
# Epoch 22:
# Loss=0.05 Batch_ID=781 Accuracy=97.20: 100%|██████████| 782/782 [00:29<00:00, 26.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9075/10000 (90.75%)
#
# Epoch 23:
# Loss=0.12 Batch_ID=781 Accuracy=97.40: 100%|██████████| 782/782 [00:29<00:00, 26.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9090/10000 (90.90%)
#
# Epoch 24:
# Loss=0.38 Batch_ID=781 Accuracy=97.66: 100%|██████████| 782/782 [00:29<00:00, 26.16it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9092/10000 (90.92%)
#
# Epoch 25:
# Loss=0.03 Batch_ID=781 Accuracy=97.73: 100%|██████████| 782/782 [00:29<00:00, 26.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9080/10000 (90.80%)
#
# Epoch 26:
# Loss=0.01 Batch_ID=781 Accuracy=97.74: 100%|██████████| 782/782 [00:29<00:00, 26.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9088/10000 (90.88%)
#
# Epoch    26: reducing learning rate of group 0 to 1.2059e-04.
# Epoch 27:
# Loss=0.16 Batch_ID=781 Accuracy=98.01: 100%|██████████| 782/782 [00:29<00:00, 26.19it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9090/10000 (90.90%)
#
# Epoch 28:
# Loss=0.57 Batch_ID=781 Accuracy=97.83: 100%|██████████| 782/782 [00:29<00:00, 26.40it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9091/10000 (90.91%)
#
# Epoch 29:
# Loss=0.04 Batch_ID=781 Accuracy=97.94: 100%|██████████| 782/782 [00:30<00:00, 26.04it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9109/10000 (91.09%)
#
# Epoch    29: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 30:
# Loss=0.01 Batch_ID=781 Accuracy=97.90: 100%|██████████| 782/782 [00:29<00:00, 26.25it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9103/10000 (91.03%)
#
# Epoch 31:
# Loss=0.00 Batch_ID=781 Accuracy=98.03: 100%|██████████| 782/782 [00:29<00:00, 26.84it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9104/10000 (91.04%)
#
# Epoch 32:
# Loss=0.06 Batch_ID=781 Accuracy=98.08: 100%|██████████| 782/782 [00:29<00:00, 26.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9097/10000 (90.97%)
#
# Epoch 33:
# Loss=0.03 Batch_ID=781 Accuracy=98.02: 100%|██████████| 782/782 [00:29<00:00, 26.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9101/10000 (91.01%)
#
# Epoch 34:
# Loss=0.12 Batch_ID=781 Accuracy=97.97: 100%|██████████| 782/782 [00:29<00:00, 26.28it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9100/10000 (91.00%)
#
# Epoch 35:
# Loss=0.08 Batch_ID=781 Accuracy=97.92: 100%|██████████| 782/782 [00:29<00:00, 26.12it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9104/10000 (91.04%)
#
# Epoch 36:
# Loss=0.10 Batch_ID=781 Accuracy=98.04: 100%|██████████| 782/782 [00:29<00:00, 26.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9088/10000 (90.88%)
#
# Epoch 37:
# Loss=0.03 Batch_ID=781 Accuracy=97.96: 100%|██████████| 782/782 [00:29<00:00, 26.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9108/10000 (91.08%)
#
# Epoch 38:
# Loss=0.01 Batch_ID=781 Accuracy=98.04: 100%|██████████| 782/782 [00:29<00:00, 26.40it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9090/10000 (90.90%)
#
# Epoch 39:
# Loss=0.04 Batch_ID=781 Accuracy=97.99: 100%|██████████| 782/782 [00:30<00:00, 26.00it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9097/10000 (90.97%)
#
# Epoch 40:
# Loss=0.02 Batch_ID=781 Accuracy=97.96: 100%|██████████| 782/782 [00:29<00:00, 26.24it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9096/10000 (90.96%)
#
# Epoch 41:
# Loss=0.05 Batch_ID=781 Accuracy=98.03: 100%|██████████| 782/782 [00:30<00:00, 25.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9107/10000 (91.07%)
#
# Epoch 42:
# Loss=0.10 Batch_ID=781 Accuracy=98.09: 100%|██████████| 782/782 [00:29<00:00, 26.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9104/10000 (91.04%)
#
# Epoch 43:
# Loss=0.02 Batch_ID=781 Accuracy=98.16: 100%|██████████| 782/782 [00:29<00:00, 26.27it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9111/10000 (91.11%)
#
# Epoch 44:
# Loss=0.02 Batch_ID=781 Accuracy=98.15: 100%|██████████| 782/782 [00:29<00:00, 26.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9106/10000 (91.06%)
#
# Epoch 45:
# Loss=0.10 Batch_ID=781 Accuracy=98.14: 100%|██████████| 782/782 [00:30<00:00, 26.00it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9100/10000 (91.00%)
#
# Epoch 46:
# Loss=0.42 Batch_ID=781 Accuracy=98.25: 100%|██████████| 782/782 [00:30<00:00, 25.96it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9096/10000 (90.96%)
#
# Epoch 47:
# Loss=0.20 Batch_ID=781 Accuracy=98.04: 100%|██████████| 782/782 [00:30<00:00, 25.87it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9106/10000 (91.06%)
#
# Epoch 48:
# Loss=0.10 Batch_ID=781 Accuracy=98.12: 100%|██████████| 782/782 [00:30<00:00, 25.61it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9102/10000 (91.02%)
#
# Epoch 49:
# Loss=0.19 Batch_ID=781 Accuracy=98.06: 100%|██████████| 782/782 [00:30<00:00, 25.37it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9108/10000 (91.08%)
#
# Epoch 50:
# Loss=0.26 Batch_ID=781 Accuracy=98.09: 100%|██████████| 782/782 [00:30<00:00, 25.28it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9095/10000 (90.95%)

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# Plot changes in training and validation accuracy

# %%
plot_metric(
    {'Training': train_accuracies, 'Validation': val_accuracies}, 'Accuracy'
)

# %% [markdown]
# ### GradCAM

# %% [markdown]
# Let's display GradCAM of any 25 misclassified images

# %%
layers = ['layer4']
grad_cam = GradCAMView(
    model, layers,
    device, dataset.mean, dataset.std
)

gradcam_views = grad_cam([x['image'] for x in incorrect_samples])
# Out:
# Mode set to GradCAM.
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2416: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
def plot_gradcam(cam_data, pred_data, classes, plot_name):
    # Initialize plot
    fig, axs = plt.subplots(len(cam_data), 2, figsize=(4, 60))

    for idx in range(len(cam_data)):
        label = classes[pred_data[idx]['label']]
        prediction = classes[pred_data[idx]['prediction']]

        axs[idx][0].axis('off')
        axs[idx][0].set_title(f'Image: {idx + 1}\nLabel: {label}')
        axs[idx][0].imshow(cam_data[idx]['image'])

        axs[idx][1].axis('off')
        axs[idx][1].set_title(f'GradCAM: {idx + 1}\nPrediction: {prediction}')
        axs[idx][1].imshow(cam_data[idx]['result']['layer4'])
    
    # Set spacing
    fig.tight_layout()
    fig.subplots_adjust(top=1.1)

    # Save image
    fig.savefig(plot_name, bbox_inches='tight')

# %%
plot_gradcam(gradcam_views, incorrect_samples, dataset.classes, 'pred_gradcam.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Result Analysis
#
# Displaying accuracy for each class in the entire validation dataset

# %%
class_level_accuracy(model, val_loader, device, dataset.classes)
# Out:
# Accuracy of plane : 92 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 87 %
# Accuracy of   cat : 81 %
# Accuracy of  deer : 90 %
# Accuracy of   dog : 83 %
# Accuracy of  frog : 94 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 94 %
# Accuracy of truck : 95 %
